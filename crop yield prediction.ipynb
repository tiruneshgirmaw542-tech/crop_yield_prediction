# %%
import pandas as pd
import numpy as np
import  seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df = pd.read_csv(r'C:\Users\admin\Documents\crop_yield_prediction\yield_df.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("yield_df.csv")
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2310)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (25932, 7)

# %%
df.describe()
# Out:
#                Year    hg/ha_yield  average_rain_fall_mm_per_year  \
# count  25932.000000   25932.000000                   25932.000000
# mean    2001.556455   76978.132925                    1146.836688
# std        7.055924   84647.605552                     717.391098
# min     1990.000000      50.000000                      51.000000
# 25%     1995.000000   19996.000000                     593.000000
# 50%     2001.000000   39530.000000                    1083.000000
# 75%     2008.000000  104168.000000                    1668.000000
# max     2013.000000  501412.000000                    3240.000000
#
#        pesticides_tonnes      avg_temp
# count       25932.000000  25932.000000
# mean        34782.573241     20.422251
# std         57228.568244      6.439402
# min             0.040000      1.300000
# 25%          1597.000000     16.580000
# 50%         15373.000000     21.420000
# 75%         45620.000000     26.060000
# max        367778.000000     30.650000

# %%
df.corr(numeric_only=True)
# Out:
#                                    Year  hg/ha_yield  \
# Year                           1.000000     0.091327
# hg/ha_yield                    0.091327     1.000000
# average_rain_fall_mm_per_year -0.006423    -0.004067
# pesticides_tonnes              0.135127     0.065523
# avg_temp                       0.013701    -0.110400
#
#                                average_rain_fall_mm_per_year  \
# Year                                               -0.006423
# hg/ha_yield                                        -0.004067
# average_rain_fall_mm_per_year                       1.000000
# pesticides_tonnes                                   0.161483
# avg_temp                                            0.333694
#
#                                pesticides_tonnes  avg_temp
# Year                                    0.135127  0.013701
# hg/ha_yield                             0.065523 -0.110400
# average_rain_fall_mm_per_year           0.161483  0.333694
# ...

# %%
#data visualization

# %%
len(df['Area'].unique())
# Out:
# 101

# %%
len(df['Item'].unique())
# Out:
# 10

# %%
plt.figure(figsize=(15,20))
sns.countplot(y='Area', data=df, hue='Area', palette='viridis', legend=False)
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.countplot(y='Item', data=df, hue='Item', palette='viridis', legend=False)
plt.show()

# %%
(df['Area'].value_counts() <400).sum()
# Out:
# np.int64(88)

# %%
country = df['Area'].unique()
yield_per_country = []

for state in country:
    yield_per_country.append(df[df['Area'] == state]['hg/ha_yield'].sum())

# %%
df['hg/ha_yield'].sum()
# Out:
# np.int64(1996196943)

# %%
yield_per_country
# Out:
# [np.int64(5711536),
#  np.int64(6711464),
#  np.int64(5722563),
#  np.int64(32864032),
#  np.int64(4524100),
#  np.int64(109111062),
#  np.int64(10852258),
#  np.int64(4608380),
#  np.int64(4384717),
#  np.int64(4443889),
#  np.int64(7720159),
#  np.int64(4704812),
#  np.int64(8442270),
#  np.int64(470651),
#  np.int64(136340329),
#  np.int64(6263075),
#  np.int64(6083337),
#  np.int64(7031146),
#  np.int64(10717883),
#  np.int64(34706922),
#  np.int64(4255627),
#  np.int64(20561214),
#  np.int64(26927138),
#  np.int64(6083167),
#  np.int64(10701651),
#  np.int64(25312166),
#  np.int64(21315591),
#  np.int64(36828848),
#  np.int64(16855944),
#  np.int64(1452416),
#  np.int64(3595638),
#  np.int64(6210668),
#  np.int64(15790618),
#  np.int64(38780463),
#  np.int64(9260371),
#  np.int64(14571925),
#  np.int64(16508723),
#  np.int64(7975743),
#  np.int64(8361103),
#  np.int64(8619194),
#  np.int64(10920131),
#  np.int64(8824110),
#  np.int64(274219558),
#  np.int64(68067328),
# ...

# %%
plt.figure(figsize=(15,20))
sns.barplot(y=country, x=yield_per_country, hue=country, palette='viridis', legend=False)
plt.show()

# %%
crops = df['Item'].unique()

yield_per_crop = []
for crop in crops:
    yield_per_crop.append(df[df['Item'] == crop]['hg/ha_yield'].sum())

# %%
plt.figure(figsize=(15,20))
sns.barplot(y=crops, x=yield_per_crop, hue=crops, palette='viridis', legend=False)
plt.show()

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.columns
# Out:
# Index(['Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
col = ['year','average_rain_fall_nn_per_year','pesticides_tonnes','avg_temp','Area', 'Item', 'Year', 'hg/ha_yield']

# %%
df.head
# Out:
# <bound method NDFrame.head of            Area            Item  Year  hg/ha_yield  \
# 0       Albania           Maize  1990        36613
# 1       Albania        Potatoes  1990        66667
# 2       Albania     Rice, paddy  1990        23333
# 3       Albania         Sorghum  1990        12500
# 4       Albania        Soybeans  1990         7000
# ...         ...             ...   ...          ...
# 28237  Zimbabwe     Rice, paddy  2013        22581
# 28238  Zimbabwe         Sorghum  2013         3066
# 28239  Zimbabwe        Soybeans  2013        13142
# 28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# 2                             1485.0             121.00     16.37
# ...

# %%
col = ['year','average_rain_fall_nn_per_year','pesticides_tonnes','avg_temp','Area', 'Item', 'Year', 'hg/ha_yield']

# %%
df = df[col]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 df = df[col]
#
# File ~\anaconda3\tiru\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\tiru\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# ...

# %%
df.head()

# %%
x = df.drop('hg/ha_yield', axis=1)
y = df['hg/ha_yield']


x.shape

# %%
y.shape

# %%
import pandas as pd

df = pd.read_csv("yield_df.csv")

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=0
)

# %%
print(df.columns)

# %%
x = df.drop('Area', axis=1)   
y = df['Area']

# %%
print(df.head())

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
print(x_train.dtypes)

# %%
num_cols = x_train.select_dtypes(include=['int64', 'float64']).columns
cat_cols = x_train.select_dtypes(include=['object']).columns

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(drop='first'), cat_cols)
    ]
)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
print(x_train.head())
print(x_train.dtypes)

# %%
from sklearn.metrics import accuracy_score

for name, md in models.items():
    md.fit(x_train_dummy, y_train)
    y_pred = md.predict(x_test_dummy)

    print("Model:", name)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("-" * 30)

# %%
from sklearn.tree import DecisionTreeClassifier

dtr = DecisionTreeClassifier()
dtr.fit(x_train_dummy, y_train)

y_pred = dtr.predict(x_test_dummy)

# %%
arry([41004., 29053., ..., 43400., 62844., 22744.])

# %%
df.columns

# %%
def prediction(year,average_rain_fall_mm_per_year, pesticides_tonnes, avg_temp,Area, Item):
    np.arry([[year,average_rain_fall_mm_per_year, pesticides_tonnes, avg_temp,Area, Item]], dtype =object)
    transform_featuers = preprocesser.transform(featurs)
    predicted_yeild = dtr.predict(transform_features).reshape(-1,1)
    return predicted_yeild[0][0]

# %%
import numpy as np

def prediction(year, average_rain_fall_mm_per_year, pesticides_tonnes, avg_temp, Area, Item):
    
    features = np.array([[year,
                          average_rain_fall_mm_per_year,
                          pesticides_tonnes,
                          avg_temp,
                          Area,
                          Item]], dtype=object)

    transform_features = preprocessor.transform(features)

    predicted_yield = dtr.predict(transform_features).reshape(-1,1)

    return predicted_yield[0][0]

# %%
preprocessor.fit(x_train)

# %%
x_train_dummy = preprocessor.transform(x_train)
x_test_dummy = preprocessor.transform(x_test)

# %%
dtr = DecisionTreeClassifier()
dtr.fit(x_train_dummy, y_train)

# %%
print(x_train.columns)
print(x_train.shape)

# %%
def prediction(year, rain, pesticides, temp, Area, Item):

    features = pd.DataFrame([[year, rain, pesticides, temp, Area, Item]],
                            columns=['Year',
                                     'average_rain_fall_mm_per_year',
                                     'pesticides_tonnes',
                                     'avg_temp',
                                     'Area',
                                     'Item'])

    transformed = preprocessor.transform(features)
    result = dtr.predict(transformed)

    return result

# %%
x = df.drop(['hg/ha_yield', 'Unnamed: 0'], axis=1)
y = df['hg/ha_yield']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=0
)

# %%
print(x_train.columns)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

num_cols = ['Year', 'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp']
cat_cols = ['Area', 'Item']

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(drop='first'), cat_cols)
    ]
)

# %%
preprocessor.fit(x_train)

# %%
x_train_dummy = preprocessor.transform(x_train)
x_test_dummy = preprocessor.transform(x_test)

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train_dummy, y_train)

# %%
def prediction(year, rain, pesticides, temp, Area, Item):

    features = pd.DataFrame([[year, rain, pesticides, temp, Area, Item]],
                            columns=x_train.columns)

    transformed = preprocessor.transform(features)

    return dtr.predict(transformed)

# %%
y = df['hg/ha_yield']

# %%
X = df.drop(['hg/ha_yield', 'Unnamed: 0'], axis=1)
y = df['hg/ha_yield']

# %%
num_cols = [
    'Year',
    'average_rain_fall_mm_per_year',
    'pesticides_tonnes',
    'avg_temp'
]

cat_cols = [
    'Area',
    'Item'
]

# %%
preprocessor.fit(x_train)

# %%
x_train_dummy = preprocessor.transform(x_train)
x_test_dummy = preprocessor.transform(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(x_train_dummy, y_train)

# %%
import pandas as pd

def prediction(year, rain, pesticides, temp, area, item):

    features = pd.DataFrame([[year, rain, pesticides, temp, area, item]],
                            columns=['Year',
                                     'average_rain_fall_mm_per_year',
                                     'pesticides_tonnes',
                                     'avg_temp',
                                     'Area',
                                     'Item'])

    transformed = preprocessor.transform(features)
    result = dtr.predict(transformed)

    return result[0]

# %%
result = prediction(1990, 1485.0, 121.0, 16.47, "Albania", "Maize")
print(result)

# %%
#import pickle
#pickle.dump(dtr, open("dtr.pkl","wb"))
#pickle.dump(preprocessor, open("preprocessor.pckle","wb"))

# %%
pickle.dump(dtr, open("dtr.pkl","wb"))
pickle.dump(preprocessor, open("preprocessor.pckle","wb"))

# %%
import os
print(os.listdir())

# %%
"preprocessor.pkl"

# %%
import pickle

pickle.dump(dtr, open("dtr.pkl","wb"))
pickle.dump(preprocessor, open("preprocessor.pkl","wb"))

print("Model saved successfully!")
